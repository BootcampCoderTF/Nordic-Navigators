# %%
# Import libraries
import pandas as pd

# %%
# load first dataset to be modified from CSV
location_df = pd.read_csv('../Resources/Processed/location.csv')
location_df
# Out:
#       Resort ID                       Resort Name Continent   Country  \
# 0             1     KitzSki – Kitzbühel/Kirchberg    Europe   Austria
# 1             2  Ischgl/Samnaun – Silvretta Arena    Europe   Austria
# 2             3   SkiWelt Wilder Kaiser-Brixental    Europe   Austria
# 3             4                       Ski Arlberg    Europe   Austria
# 4             5                Serfaus-Fiss-Ladis    Europe   Austria
# ...         ...                               ...       ...       ...
# 3220       5445                             mozir    Europe   Belarus
# 3221       5446        republican-skicenter-minsk    Europe   Belarus
# 3222       5447                           silichy    Europe   Belarus
# 3223       5467                  serra-da-estrela    Europe  Portugal
# 3224       5471              ski-centre-sandyford    Europe   Ireland
#
#      State/Province Country Code
# 0     Tyrol (Tirol)           AT
# 1     Tyrol (Tirol)           AT
# 2     Tyrol (Tirol)           AT
# 3     Tyrol (Tirol)           AT
# 4     Tyrol (Tirol)           AT
# ...             ...          ...
# 3220        Belarus           BY
# 3221        Belarus           BY
# 3222        Belarus           BY
# 3223       Portugal           PT
# 3224        Ireland           IE
#
# [3225 rows x 6 columns]

# %%
# load second dataset to be modified from CSV
price_df = pd.read_csv('../Resources/Processed/price.csv')
price_df
# Out:
#       Resort ID    Adult          Currency
# 0             1     55.0               GBP
# 1             2     53.0               GBP
# 2             3     49.0               GBP
# 3             4     53.0               GBP
# 4             5     51.0               GBP
# ...         ...      ...               ...
# 5131       5474      0.0                 -
# 5132       5475      0.0                 -
# 5133       5476  69500.0  Mongolian togrog
# 5134       5477      0.0                 -
# 5135       5478     18.0               GBP
#
# [5136 rows x 3 columns]

# %%
# Merge the two DataFrames on Resort id
merged_df = pd.merge(location_df, price_df, on='Resort ID')

merged_df
# Out:
#       Resort ID                       Resort Name Continent   Country  \
# 0             1     KitzSki – Kitzbühel/Kirchberg    Europe   Austria
# 1             2  Ischgl/Samnaun – Silvretta Arena    Europe   Austria
# 2             3   SkiWelt Wilder Kaiser-Brixental    Europe   Austria
# 3             4                       Ski Arlberg    Europe   Austria
# 4             5                Serfaus-Fiss-Ladis    Europe   Austria
# ...         ...                               ...       ...       ...
# 2938       5445                             mozir    Europe   Belarus
# 2939       5446        republican-skicenter-minsk    Europe   Belarus
# 2940       5447                           silichy    Europe   Belarus
# 2941       5467                  serra-da-estrela    Europe  Portugal
# 2942       5471              ski-centre-sandyford    Europe   Ireland
#
#      State/Province Country Code  Adult Currency
# 0     Tyrol (Tirol)           AT   55.0      GBP
# 1     Tyrol (Tirol)           AT   53.0      GBP
# 2     Tyrol (Tirol)           AT   49.0      GBP
# 3     Tyrol (Tirol)           AT   53.0      GBP
# 4     Tyrol (Tirol)           AT   51.0      GBP
# ...             ...          ...    ...      ...
# 2938        Belarus           BY    0.0        -
# 2939        Belarus           BY    0.0        -
# 2940        Belarus           BY    0.0        -
# 2941       Portugal           PT   25.0      GBP
# 2942        Ireland           IE    0.0        -
#
# [2943 rows x 8 columns]

# %%
# Filter out rows with 0.0 or no value in the adult column
filtered_df = merged_df[(merged_df['Adult'] != 0.0) & (merged_df['Adult'].notnull())]

filtered_df
# Out:
#       Resort ID                       Resort Name Continent   Country  \
# 0             1     KitzSki – Kitzbühel/Kirchberg    Europe   Austria
# 1             2  Ischgl/Samnaun – Silvretta Arena    Europe   Austria
# 2             3   SkiWelt Wilder Kaiser-Brixental    Europe   Austria
# 3             4                       Ski Arlberg    Europe   Austria
# 4             5                Serfaus-Fiss-Ladis    Europe   Austria
# ...         ...                               ...       ...       ...
# 2927       5390          sljeme-medvednica-zagreb    Europe   Croatia
# 2928       5391            velebno-baske-ostarije    Europe   Croatia
# 2934       5440              kuutse-hill-otepaeae    Europe   Estonia
# 2936       5442             vimka-viimsi-maeepark    Europe   Estonia
# 2941       5467                  serra-da-estrela    Europe  Portugal
#
#                                      State/Province Country Code  Adult  \
# 0                                     Tyrol (Tirol)           AT   55.0
# 1                                     Tyrol (Tirol)           AT   53.0
# 2                                     Tyrol (Tirol)           AT   49.0
# 3                                     Tyrol (Tirol)           AT   53.0
# 4                                     Tyrol (Tirol)           AT   51.0
# ...                                             ...          ...    ...
# 2927  Continental Croatia (Kontinentalna Hrvatska)            HR  100.0
# 2928                                        Croatia           HR   60.0
# 2934                                          Valga           EE   24.0
# 2936                                        Estonia           EE   18.0
# 2941                                       Portugal           PT   25.0
#
#            Currency
# 0               GBP
# 1               GBP
# 2               GBP
# 3               GBP
# 4               GBP
# ...             ...
# 2927  Croatian Kuna
# 2928  Croatian Kuna
# 2934            GBP
# 2936            GBP
# 2941            GBP
#
# [1923 rows x 8 columns]

# %%
# Find unique values in the Currency column
unique_currencies = filtered_df['Currency'].unique()
print(unique_currencies)
# Out:
# ['GBP' 'Bosnia convertible mark' 'Ukrainian hryvnia' 'Icelandic krona'
#  'Romanian leu' 'UK Pound' 'Hungarian forint' 'Croatian Kuna']

# %%
# Define exchange rates for conversion to GBP
exchange_rates = {
    'GBP': 1.0,
    'Bosnia convertible mark': 0.44,
    'Ukrainian hryvnia': 0.021,
    'Icelandic krona': 0.0057,
    'Romanian leu': 0.17,
    'UK Pound': 1.0,
    'Hungarian forint': 0.0022,
    'Croatian Kuna': 0.11329
}

# Perform currency conversion
def convert_to_gbp(row):
    currency = row['Currency']
    conversion_rate = exchange_rates.get(currency)
    if conversion_rate:
        return row['Adult'] * conversion_rate
    else:
        return row['Adult']

# Apply the conversion function to the Adult column
filtered_df['Adult_GBP'] = filtered_df.apply(convert_to_gbp, axis=1)

filtered_df
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_7324\925834189.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Adult_GBP'] = filtered_df.apply(convert_to_gbp, axis=1)
#       Resort ID                       Resort Name Continent   Country  \
# 0             1     KitzSki – Kitzbühel/Kirchberg    Europe   Austria
# 1             2  Ischgl/Samnaun – Silvretta Arena    Europe   Austria
# 2             3   SkiWelt Wilder Kaiser-Brixental    Europe   Austria
# 3             4                       Ski Arlberg    Europe   Austria
# 4             5                Serfaus-Fiss-Ladis    Europe   Austria
# ...         ...                               ...       ...       ...
# 2927       5390          sljeme-medvednica-zagreb    Europe   Croatia
# 2928       5391            velebno-baske-ostarije    Europe   Croatia
# 2934       5440              kuutse-hill-otepaeae    Europe   Estonia
# 2936       5442             vimka-viimsi-maeepark    Europe   Estonia
# 2941       5467                  serra-da-estrela    Europe  Portugal
#
#                                      State/Province Country Code  Adult  \
# 0                                     Tyrol (Tirol)           AT   55.0
# 1                                     Tyrol (Tirol)           AT   53.0
# 2                                     Tyrol (Tirol)           AT   49.0
# 3                                     Tyrol (Tirol)           AT   53.0
# 4                                     Tyrol (Tirol)           AT   51.0
# ...                                             ...          ...    ...
# 2927  Continental Croatia (Kontinentalna Hrvatska)            HR  100.0
# 2928                                        Croatia           HR   60.0
# 2934                                          Valga           EE   24.0
# 2936                                        Estonia           EE   18.0
# 2941                                       Portugal           PT   25.0
#
#            Currency  Adult_GBP
# 0               GBP    55.0000
# 1               GBP    53.0000
# 2               GBP    49.0000
# 3               GBP    53.0000
# 4               GBP    51.0000
# ...             ...        ...
# 2927  Croatian Kuna    11.3290
# 2928  Croatian Kuna     6.7974
# 2934            GBP    24.0000
# 2936            GBP    18.0000
# 2941            GBP    25.0000
#
# [1923 rows x 9 columns]

# %%
# Drop Adult and Currency columns
filtered_df.drop(columns=['Adult', 'Currency'], inplace=True)

# Rename Adult_GBP column to Adult Price
filtered_df.rename(columns={'Adult_GBP': 'Adult Price(£)'}, inplace=True)
# Set the values in the Adult Price column to 2 decimal points
filtered_df['Adult Price(£)'] = filtered_df['Adult Price(£)'].round(2)
filtered_df
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_7324\270621407.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.drop(columns=['Adult', 'Currency'], inplace=True)
# C:\Users\maria\AppData\Local\Temp\ipykernel_7324\270621407.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.rename(columns={'Adult_GBP': 'Adult Price(£)'}, inplace=True)
# C:\Users\maria\AppData\Local\Temp\ipykernel_7324\270621407.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Adult Price(£)'] = filtered_df['Adult Price(£)'].round(2)
#       Resort ID                       Resort Name Continent   Country  \
# 0             1     KitzSki – Kitzbühel/Kirchberg    Europe   Austria
# 1             2  Ischgl/Samnaun – Silvretta Arena    Europe   Austria
# 2             3   SkiWelt Wilder Kaiser-Brixental    Europe   Austria
# 3             4                       Ski Arlberg    Europe   Austria
# 4             5                Serfaus-Fiss-Ladis    Europe   Austria
# ...         ...                               ...       ...       ...
# 2927       5390          sljeme-medvednica-zagreb    Europe   Croatia
# 2928       5391            velebno-baske-ostarije    Europe   Croatia
# 2934       5440              kuutse-hill-otepaeae    Europe   Estonia
# 2936       5442             vimka-viimsi-maeepark    Europe   Estonia
# 2941       5467                  serra-da-estrela    Europe  Portugal
#
#                                      State/Province Country Code  \
# 0                                     Tyrol (Tirol)           AT
# 1                                     Tyrol (Tirol)           AT
# 2                                     Tyrol (Tirol)           AT
# 3                                     Tyrol (Tirol)           AT
# 4                                     Tyrol (Tirol)           AT
# ...                                             ...          ...
# 2927  Continental Croatia (Kontinentalna Hrvatska)            HR
# 2928                                        Croatia           HR
# 2934                                          Valga           EE
# 2936                                        Estonia           EE
# 2941                                       Portugal           PT
#
#       Adult Price(£)
# 0              55.00
# 1              53.00
# 2              49.00
# 3              53.00
# 4              51.00
# ...              ...
# 2927           11.33
# 2928            6.80
# 2934           24.00
# 2936           18.00
# 2941           25.00
#
# [1923 rows x 7 columns]

# %%
# Save the modified DataFrame as a new CSV file
filtered_df.to_csv('../Resources/Processed/locationsPriced.csv', index=False)

# %%
# Save the DataFrame as a JSON file
filtered_df.to_json('../Resources/Processed/locationsPriced.json', orient='records')
