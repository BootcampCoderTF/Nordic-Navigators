# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the data from the CSV files
difficulty_path = '../Resources/Processed/difficulty.csv'
names_path = '../Resources/Processed/names.csv'

difficulty_data = pd.read_csv(difficulty_path)
names_data = pd.read_csv(names_path)

# %%
merged_data = pd.merge(difficulty_data, names_data, on='Resort ID')

# %%
# Get the top 10 resort names for each category
top_10_easy_resorts = top_10_easy['NameResort']
top_10_intermediate_resorts = top_10_intermediate['NameResort']
top_10_difficult_resorts = top_10_difficult['NameResort']
# Create bar charts with increased size
plt.figure(figsize=(12, 10))

# %%
# Top 10 Resorts with Longest Easy Ski Course
sns.barplot(x='NameResort', y='Easy', data=top_10_easy, color='skyblue', ci=None,
            order=top_10_easy_resorts)
plt.title('Top 10 Resorts with Longest Easy Ski Course')
plt.xlabel('Resort Name')
plt.ylabel('Length of Easy Courses (kms)')
# Rotate the x-axis labels by 90 degrees
plt.xticks(rotation=90)
plt.show()

# Save the plot as an image in the "Images" folder
plot_name = 'Top 10 Resorts with Longest Easy Ski Course'
plt.savefig(f'Images/{plot_name}.png')
plt.close()
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_6468\1682257181.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='NameResort', y='Easy', data=top_10_easy, color='skyblue', ci=None,
# C:\Users\maria\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\maria\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Top 10 Resorts with Longest Intermediate Ski Course
sns.barplot(x='NameResort', y='Intermediate', data=top_10_intermediate, color='skyblue', ci=None,
            order=top_10_intermediate_resorts)
plt.title('Top 10 Resorts with Longest Intermediate Ski Course')
plt.xlabel('Resort Name')
plt.ylabel('Length of Intermediate Courses (kms)')
# Rotate the x-axis labels by 90 degrees
plt.xticks(rotation=90)
plt.show()

# Save the plot as an image in the "Images" folder
plot_name = 'Top 10 Resorts with Longest Intermediate Ski Course'
plt.savefig(f'Images/{plot_name}.png')
plt.close()
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_6468\1366279573.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='NameResort', y='Intermediate', data=top_10_intermediate, color='skyblue', ci=None,
# C:\Users\maria\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\maria\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Top 10 Resorts with Longest Difficult Ski Course
sns.barplot(x='NameResort', y='Difficult', data=top_10_difficult, color='skyblue', ci=None,
            order=top_10_difficult_resorts)
plt.title('Top 10 Resorts with Longest Difficult Ski Course')
plt.xlabel('Resort Name')
plt.ylabel('Length of Difficult Courses (kms)')
# Rotate the x-axis labels by 90 degrees
plt.xticks(rotation=90)
plt.show()

# Save the plot as an image in the "Images" folder
plot_name = 'Top 10 Resorts with Longest Difficult Ski Course'
plt.savefig(f'Images/{plot_name}.png')
plt.close()
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_6468\677223696.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='NameResort', y='Difficult', data=top_10_difficult, color='skyblue', ci=None,
# C:\Users\maria\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\maria\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
